# %% [markdown]
# # 2016 NHL Hockey Data Set - Sasha Kandrach

# %%
import pandas as pd 
import matplotlib.pyplot as plt 
# %matplotlib inline

# %%
df= pd.read_excel("NHL 2014-15.xls")

# %%
# !pip install xlrd
# Out:
# Requirement already satisfied (use --upgrade to upgrade): xlrd in /Users/skkandrach/.virtualenvs/lede/lib/python3.5/site-packages

# %%
df.columns.value_counts()
# Out:
# DOB               1
# GvA               1
# Sh                1
# OTA               1
# SRA GAR           1
# Cap Cost          1
# Misses            1
# Minor             1
# Ginj              1
# Grit              1
# MsS               1
# HitF              1
# End Team          1
# GVT/60            1
# S/P               1
# G                 1
# IPP               1
# OTGP              1
# FO%               1
# HF/60             1
# Days              1
# PST               1
# GWG               1
# Blocked           1
# OGVT              1
# B/60              1
# OPS               1
# dFenwick60        1
# PS/60             1
# dCFImpact         1
#                  ..
# Misc              1
# PTS               1
# Ctry              1
# dFenwickImpact    1
# Teams             1
# DPS               1
# dFFImpact         1
# +/-               1
# dCorsi60          1
# Nat               1
# dCorsiImpact      1
# OGIT              1
# TOI/G             1
# Last Name         1
# Sh GAR            1
# CoSH%             1
# PSG               1
# First Name        1
# G/60              1
# DIT               1
# SOS               1
# PS                1
# HitA              1
# Pos               1
# HT                1
# Wt                1
# Draft             1
# 3rd Star          1
# Rk                1
# 1G                1
# dtype: int64

# %% [markdown]
# # Here's all of our data:

# %%
df.head()
# Out:
#       #         DOB  Birth City  S/P Ctry  Nat  HT   Wt  S   Draft    ...     \
# 0   8.0  Feb 25 '87    Muskegon   MI  USA   US  74  218  L  2005.0    ...
# 1  41.0  Jul 16 '87       Edina   MN  USA   US  75  202  L     NaN    ...
# 2  25.0  Jun 18 '90  St. John's   NL  CAN   CA  74  206  L  2008.0    ...
# 3  27.0  Apr 26 '77       Seria  NaN  BRN  NaN  72  200  R  1996.0    ...
# 4  32.0  Jan 03 '91   Kleinburg   ON  CAN   CA  70  187  L     NaN    ...
#
#    dFAImpact  dFenwickImpact dFenwick60  Days  Ginj          Injury Cap Cost  \
# 0     -49.38           -9.36      -0.60   186  11.0  Hand, Shoulder    1.800
# 1      -6.27           10.41      22.57    29   NaN             NaN    0.106
# 2      -4.07            0.95       3.33     5   NaN             NaN    0.017
# 3      -1.23          -19.42      -2.36   186   5.0     Undisclosed    0.700
# 4       1.05            0.41       2.26     2   NaN             NaN    0.006
#
#     CHIP  Bonuses       GVS
# 0  0.088      0.0  5.340426
# 1  0.000      0.0 -0.443079
# 2  0.000      0.0 -0.104713
# 3  0.043      0.0  0.980851
# 4  0.000      0.0  0.299817
#
# [5 rows x 120 columns]

# %% [markdown]
# # Here are each of the columns in the data set:

# %%
df.columns
# Out:
# Index(['#', 'DOB', 'Birth City', 'S/P', 'Ctry', 'Nat', 'HT', 'Wt', 'S',
#        'Draft',
#        ...
#        'dFenwickImpact', 'dFenwick60', 'Days', 'Ginj', 'Injury', 'Cap Cost',
#        'CHIP', 'Bonuses', 'GVS', 'birthyear'],
#       dtype='object', length=121)

# %% [markdown]
# # Let's count how many players are from each country:

# %%
df['Ctry'].value_counts().head(10)
# Out:
# CAN    453
# USA    222
# SWE     64
# CZE     33
# RUS     29
# FIN     25
# SVK     11
# CHE     10
# DEU      9
# DNK      7
# Name: Ctry, dtype: int64

# %% [markdown]
# # Let's count how many players are from each country: they're basically the same but in some cases are slightly different

# %%
df['Nat'].value_counts().head(10)
# Out:
# CA    454
# US    221
# SE     64
# CZ     33
# RU     30
# FI     25
# SK     11
# CH     10
# DE      8
# DK      7
# Name: Nat, dtype: int64

# %% [markdown]
# # And now let's look at the top ten highest birth cities

# %%
df['Birth City'].value_counts().head(10)
# Out:
# Toronto        33
# Edmonton       25
# Winnipeg       15
# Ottawa         14
# Calgary        12
# Montreal       11
# Stockholm      10
# Mississauga    10
# London          9
# Minneapolis     8
# Name: Birth City, dtype: int64

# %% [markdown]
# # Let's look at how many of those Toronto-born players were drafted before 2006

# %%
df[(df['Birth City'] == 'Toronto') & (df['Draft'] < 2006.0)].head()
# Out:
#         #         DOB Birth City S/P Ctry Nat  HT   Wt  S   Draft    ...     \
# 60   46.0  Dec 15 '86    Toronto  ON  CAN  CA  76  216  R  2005.0    ...
# 113  23.0  Jun 08 '82    Toronto  ON  CAN  CA  69  190  L  2001.0    ...
# 142  16.0  Apr 25 '87    Toronto  ON  CAN  CA  70  207  L  2005.0    ...
# 145   7.0  Jun 14 '87    Toronto  ON  CAN  CA  70  184  L  2005.0    ...
# 146  26.0  Jan 27 '83    Toronto  ON  CAN  CA  73  200  L  2001.0    ...
#
#      dFAImpact  dFenwickImpact dFenwick60  Days  Ginj  \
# 60        0.15           -3.56     -10.64     5   NaN
# 113      33.61          -78.72      -4.99   186  14.0
# 142       1.00           -2.48     -26.62    21   NaN
# 145      12.05          -22.59      -1.36   186   NaN
# 146     -42.93           73.10       8.63   164   1.0
#
#                                    Injury Cap Cost   CHIP  Bonuses       GVS
# 60                                    NaN    0.016  0.000      0.0 -0.202585
# 113  Illness, Jaw, Lower body, Upper body    5.000  0.122      0.0  0.031915
# 142                                   NaN    0.096  0.000      0.0 -0.072135
# 145                                   NaN    3.000  0.000      0.0  1.187234
# 146                                   Flu    0.551  0.008      0.0  1.959460
#
# [5 rows x 120 columns]

# %% [markdown]
# # Let's look at how many of those Edmonton-born players were drafted before 2006

# %%
df[(df['Birth City'] == 'Edmonton') & (df['Draft'] < 2006.0)].head()
# Out:
#         #         DOB Birth City S/P Ctry Nat  HT   Wt  S   Draft    ...     \
# 80   19.0  Sep 27 '83   Edmonton  AB  CAN  CA  76  212  L  2002.0    ...
# 82   55.0  Jan 19 '84   Edmonton  AB  CAN  CA  74  225  R  2002.0    ...
# 130  25.0  May 02 '79   Edmonton  AB  CAN  CA  75  213  L  1997.0    ...
# 224  29.0  Apr 03 '82   Edmonton  AB  CAN  CA  74  215  R  2000.0    ...
# 240  21.0  Mar 17 '79   Edmonton  AB  CAN  CA  71  184  L  1997.0    ...
#
#      dFenwickImpact  dFenwick60 Days  Ginj                  Injury Cap Cost  \
# 80           -56.56       -2.73  186  10.0              Flu, Groin    5.400
# 82           114.43        5.87  186  10.0  Lower body, Upper body    3.367
# 130          -67.64       -4.82  186   NaN                     NaN    2.000
# 224          -16.22       -0.95  186   4.0     Illness, Lower body    2.917
# 240          -87.87       -4.54  186   9.0              Concussion    3.250
#
#       CHIP Bonuses       GVS birthyear
# 80   0.132     0.0 -6.219149        83
# 82   0.041     0.0  4.006383        84
# 130  0.000     0.0 -1.285106        79
# 224  0.036     0.0 -4.436170        82
# 240  0.357     0.0 -3.044681        79
#
# [5 rows x 121 columns]

# %% [markdown]
# # Let's look at how many of those Minneapolis-born players were drafted before 2006

# %%
df[(df['Birth City'] == 'Minneapolis') & (df['Draft'] < 2006.0)].head()
# Out:
#         #         DOB   Birth City S/P Ctry Nat  HT   Wt  S   Draft    ...     \
# 22   42.0  May 01 '84  Minneapolis  MN  USA  US  75  221  R  2003.0    ...
# 503   7.0  Mar 05 '81  Minneapolis  MN  USA  US  73  200  L  2000.0    ...
# 542  39.0  Jan 09 '84  Minneapolis  MN  USA  US  73  190  L  2004.0    ...
# 606  11.0  Jul 28 '84  Minneapolis  MN  USA  US  71  197  L  2003.0    ...
#
#      dFAImpact  dFenwickImpact dFenwick60  Days Ginj                Injury  \
# 22       20.59            0.67       0.04   186  1.0            Concussion
# 503     -23.59            6.78       0.32   186  8.0           Undisclosed
# 542     -15.11           10.19       9.43    26  NaN                   NaN
# 606      23.85          -40.65      -2.28   186  6.0  Concussion, Soreness
#
#     Cap Cost   CHIP  Bonuses       GVS
# 22     4.500  0.055      0.0  4.295745
# 503    5.000  0.488      0.0 -1.068085
# 542    0.077  0.000      0.0 -0.100252
# 606    7.538  0.460      0.0  2.431915
#
# [4 rows x 120 columns]

# %% [markdown]
# # Concussions...that's always a fun topic. Let's look at the players from each country that reported a concussion. We'll start with the United States:

# %%
usa_concussion = df[(df['Ctry'] == 'USA') & (df['Injury'] == 'Concussion')]

# %%
usa_concussion[["First Name", "Last Name"]]
# Out:
#     First Name Last Name
# 22       David    Backes
# 358       Jack    Hillen

# %% [markdown]
# # Hmmm... only two reported concussions in professional hockey?! highly doubtful...let's look at the injuries that were reported as 'Undisclosed' and call them mystery injuries:

# %%
usa_mystery_injury = df[(df['Ctry'] == 'USA') & (df['Injury'] == 'Undisclosed')]

# %%
usa_mystery_injury[["First Name", "Last Name"]]
# Out:
#     First Name  Last Name
# 295       Alex  Goligoski
# 503       Paul     Martin
# 631      Corey     Potter
# 727       Drew      Shore

# %%
us_concussion
# Out:
#         #         DOB   Birth City S/P Ctry Nat  HT   Wt  S   Draft    ...     \
# 22   42.0  May 01 '84  Minneapolis  MN  USA  US  75  221  R  2003.0    ...
# 358  38.0  Jan 24 '86   Minnetonka  MN  USA  US  70  190  L     NaN    ...
#
#      dFAImpact  dFenwickImpact dFenwick60  Days  Ginj      Injury Cap Cost  \
# 22       20.59            0.67       0.04   186   1.0  Concussion      4.5
# 358      28.36          -51.88     -13.89   186  19.0  Concussion      0.7
#
#       CHIP  Bonuses       GVS
# 22   0.055      0.0  4.295745
# 358  0.162      0.0  0.080851
#
# [2 rows x 120 columns]

# %% [markdown]
# # Let's look at Canada's reported concussions:

# %%
can_concussion = df[(df['Ctry'] == 'CAN') & (df['Injury'] == 'Concussion')]

# %%
can_concussion[["First Name", "Last Name"]]
# Out:
#     First Name Last Name
# 141      Ryane     Clowe
# 240     Andrew   Ference
# 241    Michael   Ferland
# 261       Matt    Fraser

# %% [markdown]
# # Hmmm...not a lot either. Let's look at the "undisclosed" injuries that were reported:

# %%
can_mystery_injury = df[(df['Ctry'] == 'CAN') & (df['Injury'] == 'Undisclosed')]

# %%
can_mystery_injury[["First Name", "Last Name"]]
# Out:
#      First Name  Last Name
# 48      Patrice   Bergeron
# 64    Alexandre     Bolduc
# 138  Marc-Andre     Cliche
# 211      Jordan     Eberle
# 299     Barclay    Goodrow
# 326        Matt  Halischuk
# 402       Nazem      Kadri
# 412       Chris      Kelly
# 477       Bryan     Little
# 481       Milan      Lucic
# 495        Brad   Marchand
# 502        Matt     Martin
# 515         Tye     McGinn
# 669       Brett    Ritchie
# 776         Ben     Street
# 856     Patrick  Wiercioch

# %% [markdown]
# # Switzerland Concussions:

# %%
che_concussion = df[(df['Ctry'] == 'CHE') & (df['Injury'] == 'Concussion')]

# %%
che_concussion[["First Name", "Last Name"]]
# Out:
# Empty DataFrame
# Columns: [First Name, Last Name]
# Index: []

# %% [markdown]
# # Switzerland "Undisclosed Injuries"

# %%
che_mystery_injury = df[(df['Ctry'] == 'CHE') & (df['Injury'] == 'Undisclosed')]

# %%
che_mystery_injury[["First Name", "Last Name"]]
# Out:
#     First Name Last Name
# 191    Raphael      Diaz

# %% [markdown]
# # Sweden Concussions:

# %%
swe_concussion = df[(df['Ctry'] == 'SWE') & (df['Injury'] == 'Concussion')]

# %%
swe_concussion[["First Name", "Last Name"]]
# Out:
# Empty DataFrame
# Columns: [First Name, Last Name]
# Index: []

# %% [markdown]
# # Sweden "Undisclosed" Injuries

# %%
swe_mystery_injury = df[(df['Ctry'] == 'SWE') & (df['Injury'] == 'Undisclosed')]

# %%
swe_mystery_injury[["First Name", "Last Name"]]
# Out:
# Empty DataFrame
# Columns: [First Name, Last Name]
# Index: []

# %% [markdown]
# # Germany Concussions:

# %%
deu_concussion = df[(df['Ctry'] == 'DEU') & (df['Injury'] == 'Concussion')]

# %%
deu_concussion[["First Name", "Last Name"]]
# Out:
#     First Name Last Name
# 366  Korbinian    Holzer

# %% [markdown]
# # Germany "Undisclosed" Injuries:

# %%
deu_mystery_injury = df[(df['Ctry'] == 'DEU') & (df['Injury'] == 'Undisclosed')]

# %%
deu_mystery_injury[["First Name", "Last Name"]]
# Out:
# Empty DataFrame
# Columns: [First Name, Last Name]
# Index: []

# %% [markdown]
# # Czech Republic Concussions:

# %%
cze_concussion= df[(df['Ctry'] == 'CZE') & (df['Injury'] == 'Concussion')]

# %%
cze_concussion[["First Name", "Last Name"]]
# Out:
# Empty DataFrame
# Columns: [First Name, Last Name]
# Index: []

# %% [markdown]
# # Czech Republic "Undisclosed Injuries"

# %%
cze_mystery_injury = df[(df['Ctry'] == 'CZE') & (df['Injury'] == 'Undisclosed')]

# %%
cze_mystery_injury[["First Name", "Last Name"]]
# Out:
#     First Name    Last Name
# 249      Tomas  Fleischmann

# %% [markdown]
# # Russia Concussions:

# %%
rus_concussion = df[(df['Ctry'] == 'RUS') & (df['Injury'] == 'Concussion')]

# %%
rus_concussion[["First Name", "Last Name"]]
# Out:
# Empty DataFrame
# Columns: [First Name, Last Name]
# Index: []

# %% [markdown]
# # Russia "Undisclosed Injuries"

# %%
rus_mystery_injury = df[(df['Ctry'] == 'RUS') & (df['Injury'] == 'Undisclosed')]

# %%
rus_mystery_injury[["First Name", "Last Name"]]
# Out:
#     First Name Last Name
# 794     Daniil   Tarasov

# %% [markdown]
# # Lithuania Concussions

# %%
ltu_concussion = df[(df['Ctry'] == 'LTU') & (df['Injury'] == 'Concussion')]

# %%
ltu_concussion[["First Name", "Last Name"]]
# Out:
# Empty DataFrame
# Columns: [First Name, Last Name]
# Index: []

# %% [markdown]
# # Lithuania "Undisclosed Injuries"

# %%
ltu_mystery_injury = df[(df['Ctry'] == 'LTU') & (df['Injury'] == 'Undisclosed')]

# %%
ltu_mystery_injury[["First Name", "Last Name"]]
# Out:
# Empty DataFrame
# Columns: [First Name, Last Name]
# Index: []

# %% [markdown]
# # Norway Concussions

# %%
nor_concussion = df[(df['Ctry'] == 'NOR') & (df['Injury'] == 'Concussion')]

# %%
nor_concussion[["First Name", "Last Name"]]
# Out:
# Empty DataFrame
# Columns: [First Name, Last Name]
# Index: []

# %% [markdown]
# # Norway "Undisclosed" Injuries

# %%
nor_mystery_injury = df[(df['Ctry'] == 'NOR') & (df['Injury'] == 'Undisclosed')]

# %%
nor_mystery_injury[["First Name", "Last Name"]]
# Out:
# Empty DataFrame
# Columns: [First Name, Last Name]
# Index: []

# %%
df
# Out:
#         #         DOB     Birth City  S/P Ctry  Nat  HT   Wt  S   Draft  \
# 0     8.0  Feb 25 '87       Muskegon   MI  USA   US  74  218  L  2005.0
# 1    41.0  Jul 16 '87          Edina   MN  USA   US  75  202  L     NaN
# 2    25.0  Jun 18 '90     St. John's   NL  CAN   CA  74  206  L  2008.0
# 3    27.0  Apr 26 '77          Seria  NaN  BRN  NaN  72  200  R  1996.0
# 4    32.0  Jan 03 '91      Kleinburg   ON  CAN   CA  70  187  L     NaN
# 5    42.0  Jun 03 '90         Ottawa   ON  CAN   CA  70  190  R     NaN
# 6     6.0  Aug 21 '80       Kingston   ON  CAN   CA  77  223  L  1998.0
# 7     NaN  Jan 31 '90        Chicago   IL  USA   US  73  210  L     NaN
# 8    39.0  Oct 18 '91    Kansas City   MO  USA   US  76  201  R  2010.0
# 9    27.0  Sep 24 '88        Burnaby   BC  CAN   CA  74  217  L  2007.0
# 10   53.0  May 07 '94     Burlington   ON  CAN   CA  75  212  R  2012.0
# 11   18.0  Feb 05 '89       Munkedal  NaN  SWE   SE  74  211  L  2007.0
# 12   15.0  May 17 '91      Pickering   ON  CAN   CA  73  207  L  2011.0
# 13   58.0  Mar 21 '93         Zurich  NaN  CHE   CH  69  183  L  2013.0
# 14   15.0  Jun 27 '85     Woodbridge   ON  CAN   CA  73  212  L     NaN
# 15   42.0  May 24 '88      Yaroslavl  NaN  RUS   RU  76  198  L  2006.0
# 16   36.0  Aug 12 '88        Milford   CT  USA   US  68  172  R     NaN
# 17   33.0  May 31 '93           Pori  NaN  FIN   FI  75  192  R  2011.0
# 18   38.0  Apr 08 '93     Skellefteå  NaN  SWE   SE  69  172  R  2014.0
# 19   37.0  Apr 01 '91       Winnipeg   MB  CAN   CA  75  215  L  2009.0
# 20   13.0  Jun 05 '89      Riverside   CT  USA   US  68  174  R  2008.0
# 21   22.0  Jun 11 '89        Rouleau   SK  CAN   CA  78  222  L  2007.0
# 22   42.0  May 01 '84    Minneapolis   MN  USA   US  75  221  R  2003.0
# 23   11.0  Mar 17 '89       Vasteras  NaN  SWE   SE  72  198  L  2007.0
# 24   19.0  Nov 23 '87          Gävle  NaN  SWE   SE  73  208  L  2006.0
# 25   47.0  Oct 05 '92           Bern  NaN  CHE   CH  71  190  L  2011.0
# 26   37.0  Oct 27 '91      ANCHORAGE   AK  USA   US  75  195  R     NaN
# 27   12.0  Oct 02 '89    Bowmanville   ON  CAN   CA  73  194  L  2008.0
# 28    2.0  Nov 26 '82       Baudette   MN  USA   US  71  204  L  2002.0
# 29    8.0  Mar 23 '90       Montreal   QC  CAN   CA  73  199  L  2008.0
# ..    ...         ...            ...  ...  ...  ...  ..  ... ..     ...
# 852  26.0  Aug 31 '86       Plymouth   MN  USA   US  77  225  R  2004.0
# 853  25.0  Mar 17 '88        Brandon   MB  CAN   CA  72  201  R  2006.0
# 854  33.0  Feb 06 '88        Reading   MA  USA   US  66  170  L     NaN
# 855   6.0  Mar 20 '83      Kitchener   ON  CAN   CA  72  200  R  2002.0
# 856  46.0  Sep 12 '90        Burnaby   BC  CAN   CA  77  206  L  2008.0
# 857  14.0  Oct 04 '81        Cobourg   ON  CAN   CA  73  189  R  2000.0
# 858  33.0  Oct 20 '89      Greenwich   CT  USA   US  73  216  L  2008.0
# 859  28.0  Mar 16 '91         Barrie   ON  CAN   CA  74  199  L  2009.0
# 860  44.0  Feb 03 '87        Windsor   ON  CAN   CA  73  210  L     NaN
# 861  43.0  Apr 24 '92       Oakville   ON  CAN   CA  71  183  L  2011.0
# 862  43.0  Mar 29 '94        Toronto   ON  CAN   CA  76  210  R  2012.0
# 863  57.0  Apr 12 '88       Evanston   IL  USA   US  72  200  R  2008.0
# 864  26.0  Mar 06 '85        Toronto   ON  CAN   CA  74  207  L  2004.0
# 865  20.0  Feb 21 '84         Canton   MI  USA   US  71  203  R  2002.0
# 866  53.0  Apr 14 '90        Holland   MI  USA   US  74  200  R  2008.0
# 867  45.0  Sep 15 '89     Dusseldorf  NaN  DEU  NaN  75  215  L     NaN
# 868  56.0  Jun 11 '92       Humboldt   SK  CAN   CA  76  210  L  2012.0
# 869  26.0  Mar 12 '93        Burnaby   BC  CAN   CA  74  210  L  2011.0
# 870  39.0  Oct 04 '94    Nizhnekamsk  NaN  RUS   RU  77  232  L  2013.0
# 871  10.0  Oct 06 '93    Nizhnekamsk  NaN  RUS   RU  71  197  L  2012.0
# 872  93.0  Sep 09 '86         Boston   MA  USA   US  73  190  L  2005.0
# 873  51.0  Apr 16 '95         Moscow  NaN  RUS   RU  77  220  L  2013.0
# 874  19.0  May 13 '85       Winnipeg   MB  CAN   CA  75  205  R  2004.0
# 875  40.0  Oct 09 '80       Njurunda  NaN  SWE   SE  72  195  L  1999.0
# 876  93.0  Apr 18 '93      Stockholm  NaN  SWE   SE  74  211  R  2011.0
# 877  28.0  Feb 03 '77           Most  NaN  CZE   CZ  71  190  R  2001.0
# 878  16.0  Sep 01 '87        Toronto   ON  CAN   CA  72  185  L     NaN
# 879   8.0  Jun 16 '78     Elektrenai  NaN  LTU   LT  77  225  L  1996.0
# 880  36.0  Sep 01 '87           Oslo  NaN  NOR   NO  67  179  L     NaN
# 881  16.0  Jan 16 '92  Newport Beach   CA  USA   US  71  188  L  2010.0
#
#        ...      dFAImpact  dFenwickImpact dFenwick60  Days  Ginj  \
# 0      ...         -49.38           -9.36      -0.60   186  11.0
# 1      ...          -6.27           10.41      22.57    29   NaN
# 2      ...          -4.07            0.95       3.33     5   NaN
# 3      ...          -1.23          -19.42      -2.36   186   5.0
# 4      ...           1.05            0.41       2.26     2   NaN
# 5      ...          16.55          -20.56     -12.23    54   NaN
# 6      ...          -4.29            6.21       4.94   186  20.0
# 7      ...          -5.61            2.45       3.25     8   NaN
# 8      ...          -3.12            3.85      21.90     2   NaN
# 9      ...         -28.35          -17.26      -0.77   186   NaN
# 10     ...          -1.63           -3.28      -2.36    11   NaN
# 11     ...          26.23          -45.28      -4.40   186   1.0
# 12     ...          13.86          -37.39     -14.32   186   NaN
# 13     ...           3.80          -10.55      -6.93    35   NaN
# 14     ...          -1.15           -4.45     -11.43     8   NaN
# 15     ...         -33.36           63.66       6.07   186  30.0
# 16     ...         -14.43           23.20       9.94   186   NaN
# 17     ...          -2.40           -1.27      -5.21     1   NaN
# 18     ...          -4.01           -2.54      -2.48    12   NaN
# 19     ...          -1.29           -1.24      -1.70    48   NaN
# 20     ...          49.06          -16.26      -0.97   186   4.0
# 21     ...          23.49          -16.16      -2.31   160   NaN
# 22     ...          20.59            0.67       0.04   186   1.0
# 23     ...         -30.05           52.88       4.40   186  30.0
# 24     ...          -6.38           35.33       1.67   186   NaN
# 25     ...          -2.91           -2.09      -7.16    60   1.0
# 26     ...          -8.62            9.56      10.93    18   NaN
# 27     ...          54.97          -87.98      -5.23   186  12.0
# 28     ...          16.96          -20.28      -7.84   186  64.0
# 29     ...          11.86          -19.31      -1.42   186   NaN
# ..     ...            ...             ...        ...   ...   ...
# 852    ...          -4.04           42.46       2.36   186   2.0
# 853    ...         -17.80           24.68       4.08   166  39.0
# 854    ...           4.44           -8.44     -18.07    11   NaN
# 855    ...          67.40         -139.37      -5.40   186   NaN
# 856    ...         -28.92          100.40       7.37   186   8.0
# 857    ...          -8.93           11.96       0.65   186   1.0
# 858    ...           4.04            9.07       0.53   186   5.0
# 859    ...          -0.48            1.82       6.93     5   NaN
# 860    ...          -1.24            1.95       4.76   186  78.0
# 861    ...           0.64           -1.62     -28.10    46  18.0
# 862    ...         -30.70           30.22       2.49   178   9.0
# 863    ...          67.32          -94.60      -5.77   186   7.0
# 864    ...         -68.10           85.03      12.63   186   2.0
# 865    ...          25.34           22.66       9.55   186   8.0
# 866    ...          -0.07            2.47       0.66    62   NaN
# 867    ...          -1.49            0.62       1.47    26   3.0
# 868    ...          -0.34           -3.07     -14.64     3   NaN
# 869    ...          -5.51            2.99      10.24    22   NaN
# 870    ...          -1.24           -1.06      -6.35     2   NaN
# 871    ...          81.92          -88.83      -5.06   186   1.0
# 872    ...          45.70          -32.70      -2.86   186   NaN
# 873    ...          -4.39           26.28       1.72   186   NaN
# 874    ...         -35.79           14.40       0.82   186   8.0
# 875    ...          -1.97          -50.04      -2.70   186   4.0
# 876    ...          31.06          -42.91      -2.56   186   NaN
# 877    ...         -34.31            3.98       3.35   186   NaN
# 878    ...          -1.24           -1.26      -3.66     4   NaN
# 879    ...          -3.20          -11.44      -0.73   186   8.0
# 880    ...         -29.64           15.78       0.87   186   4.0
# 881    ...         -11.67           23.26       2.15   186  31.0
#
#                                         Injury Cap Cost   CHIP  Bonuses  \
# 0                               Hand, Shoulder    1.800  0.088    0.000
# 1                                          NaN    0.106  0.000    0.000
# 2                                          NaN    0.017  0.000    0.000
# 3                                  Undisclosed    0.700  0.043    0.000
# 4                                          NaN    0.006  0.000    0.000
# 5                                          NaN    0.167  0.000    0.000
# 6                              Lower body, Flu    3.022  0.854    0.000
# 7                                          NaN    0.076  0.000    0.850
# 8                                          NaN    0.010  0.000    0.110
# 9                                          NaN    2.800  0.000    0.000
# 10                                         NaN    0.053  0.000    0.282
# 11                                     Illness    0.733  0.009    0.000
# 12                                         NaN    0.550  0.000    0.000
# 13                                         NaN    0.141  0.000    0.125
# 14                                         NaN    0.028  0.000    0.000
# 15                             Arm, Concussion    3.283  0.921    0.000
# 16                                         NaN    0.601  0.000    0.000
# 17                                         NaN    0.007  0.000    0.700
# 18                                         NaN    0.042  0.000    0.035
# 19                                         NaN    0.219  0.000    0.000
# 20                          Facial, Upper body    1.150  0.014    0.000
# 21                                         NaN    0.688  0.000    0.000
# 22                                  Concussion    4.500  0.055    0.000
# 23                          Abdominal, Illness    1.500  0.530    0.000
# 24                                         NaN    6.700  0.000    0.000
# 25                                     Illness    0.460  0.017    1.062
# 26                                         NaN    0.131  0.000    0.025
# 27   Hand, Lower body, Undisclosed, Upper body    3.300  0.322    0.000
# 28                         Concussion, Illness    1.500  1.024    0.000
# 29                                         NaN    0.874  0.000    0.000
# ..                                         ...      ...    ...      ...
# 852                                 Lower body    5.600  0.137    0.000
# 853                                   Pectoral    0.513  0.273    0.000
# 854                                        NaN    0.034  0.000    0.000
# 855                                        NaN    5.250  0.000    0.000
# 856                                Undisclosed    2.000  0.122    0.000
# 857                                        Eye    3.650  0.045    0.000
# 858                     Lower body, Upper body    2.000  0.049    0.000
# 859                                        NaN    0.019  0.000    0.000
# 860                      Shoulder, Undisclosed    2.250  2.058    0.000
# 861                                        Leg    0.153  0.203    0.282
# 862                      Head, Leg, Lower body    1.238  0.032    0.400
# 863                                       Hand    2.475  0.211    0.000
# 864                                       Head    1.139  0.032    0.000
# 865                   Foot, Finger, Lower body    5.500  0.402    0.000
# 866                                        NaN    0.292  0.000    0.247
# 867                                        Leg    0.129  0.034    0.058
# 868                                        NaN    0.012  0.000    0.025
# 869                                        NaN    0.109  0.000    0.000
# 870                                        NaN    0.010  0.000    0.133
# 871                                      Groin    3.775  0.046    2.850
# 872                                        NaN    4.658  0.000    0.000
# 873                                        NaN    1.744  0.000    0.850
# 874                                 Lower body    5.750  0.561    0.000
# 875                                       Head    6.083  0.297    0.000
# 876                                        NaN    1.744  0.000    0.850
# 877                                        NaN    3.779  0.000    2.000
# 878                                        NaN    0.013  0.000    0.000
# 879                                        Leg    3.100  0.302    0.000
# 880             Lower body, Shoulder, Soreness    3.500  0.043    0.000
# 881                        Collarbone, Illness    0.900  0.296    0.000
#
#            GVS
# 0     5.340426
# 1    -0.443079
# 2    -0.104713
# 3     0.980851
# 4     0.299817
# 5    -0.515580
# 6    -5.159574
# 7    -0.411370
# 8    -0.208694
# 9     2.412766
# 10   -0.543560
# 11   -0.689362
# 12    1.000000
# 13   -0.279799
# 14   -0.009243
# 15   -2.814894
# 16    5.491489
# 17   -0.008602
# 18   -0.213864
# 19   -0.763967
# 20    5.623404
# 21   -0.957195
# 22    4.295745
# 23    4.678723
# 24    2.314894
# 25    0.298765
# 26    0.334523
# 27    2.548936
# 28   -2.821277
# 29   -0.589362
# ..         ...
# 852   3.855319
# 853   3.052894
# 854  -0.103134
# 855   4.900000
# 856  -2.085106
# 857   1.104255
# 858   6.914894
# 859  -0.408968
# 860  -4.217021
# 861  -0.036124
# 862  -0.514162
# 863   3.104255
# 864   9.546809
# 865  -6.331915
# 866  -0.831206
# 867  -0.110890
# 868  -0.206658
# 869  -0.093503
# 870  -0.208694
# 871  -6.261702
# 872  -0.540426
# 873  -2.140426
# 874 -10.463830
# 875  -1.672340
# 876   6.159574
# 877  -1.970213
# 878  -0.202494
# 879  -7.525532
# 880   3.423404
# 881   6.255319
#
# [882 rows x 120 columns]

# %% [markdown]
# # Let's look at how old the players are:

# %%
birthdate = df[df['DOB']].replace("DOB", "")
birthdate
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-251-1147b0de488d> in <module>()
# ----> 1 birthdate = df[df['DOB']].replace("DOB", "")
#       2 birthdate
#
# /Users/skkandrach/.virtualenvs/lede/lib/python3.5/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    1989         if isinstance(key, (Series, np.ndarray, Index, list)):
#    1990             # either boolean or fancy integer index
# -> 1991             return self._getitem_array(key)
#    1992         elif isinstance(key, DataFrame):
#    1993             return self._getitem_frame(key)
#
# /Users/skkandrach/.virtualenvs/lede/lib/python3.5/site-packages/pandas/core/frame.py in _getitem_array(self, key)
#    2033             return self.take(indexer, axis=0, convert=False)
#    2034         else:
# -> 2035             indexer = self.ix._convert_to_indexer(key, axis=1)
#    2036             return self.take(indexer, axis=1, convert=True)
#    2037
#
# /Users/skkandrach/.virtualenvs/lede/lib/python3.5/site-packages/pandas/core/indexing.py in _convert_to_indexer(self, obj, axis, is_setter)
#    1212                 mask = check == -1
#    1213                 if mask.any():
# -> 1214                     raise KeyError('%s not in index' % objarr[mask])
#    1215
#    1216                 return _values_from_object(indexer)
#
# KeyError: '["Feb 25 \'87" "Jul 16 \'87" "Jun 18 \'90" "Apr 26 \'77" "Jan 03 \'91"\n "Jun 03 \'90" "Aug 21 \'80" "Jan 31 \'90" "Oct 18 \'91" "Sep 24 \'88"\n "May 07 \'94" "Feb 05 \'89" "May 17 \'91" "Mar 21 \'93" "Jun 27 \'85"\n "May 24 \'88" "Aug 12 \'88" "May 31 \'93" "Apr 08 \'93" "Apr 01 \'91"\n "Jun 05 \'89" "Jun 11 \'89" "May 01 \'84" "Mar 17 \'89" "Nov 23 \'87"\n "Oct 05 \'92" "Oct 27 \'91" "Oct 02 \'89" "Nov 26 \'82" "Mar 23 \'90"\n "Sep 02 \'95" "Jul 26 \'91" "Jun 04 \'88" "Feb 17 \'88" "May 04 \'92"\n "Oct 16 \'85" "Jun 04 \'80" "Dec 05 \'92" "May 13 \'91" "Jun 07 \'88"\n "Mar 06 \'85" "Jun 25 \'88" "Jul 18 \'89" "Jul 26 \'87" "Nov 27 \'91"\n "Jun 20 \'96" "Jan 06 \'84" "Feb 08 \'84" "Jul 24 \'85" "Jun 02 \'88"\n "Mar 31 \'85" "Oct 02 \'86" "Mar 09 \'86" "Apr 04 \'88" "Sep 29 \'91"\n "Jun 16 \'81" "Jul 15 \'90" "Jul 17 \'92" "Apr 19 \'91" "Jan 30 \'89"\n "Dec 15 \'86" "Jan 25 \'85" "Dec 16 \'89" "Jul 15 \'90" "Jun 26 \'85"\n "May 13 \'86" "Jun 05 \'86" "Jan 31 \'87" "Apr 20 \'88" "Nov 24 \'84"\n "Mar 23 \'86" "Jul 12 \'89" "Mar 18 \'89" "Sep 08 \'93" "Aug 17 \'76"\n "Mar 25 \'90" "May 31 \'92" "Sep 23 \'90" "Dec 10 \'81" "Jan 03 \'91"\n "Sep 27 \'83" "Mar 08 \'89" "Jan 19 \'84" "Oct 04 \'89" "Apr 17 \'82"\n "Dec 18 \'84" "Jul 12 \'76" "Mar 19 \'86" "Sep 22 \'87" "Feb 10 \'87"\n "Apr 03 \'89" "Apr 17 \'79" "Oct 06 \'77" "Jun 07 \'90" "Jul 12 \'93"\n "May 25 \'84" "Dec 05 \'86" "Aug 17 \'85" "Feb 03 \'91" "Nov 04 \'84"\n "Jul 02 \'90" "Jun 24 \'85" "May 29 \'92" "Mar 09 \'86" "Feb 09 \'95"\n "Jan 06 \'83" "Mar 09 \'85" "Apr 11 \'81" "Oct 27 \'86" "Mar 27 \'85"\n "Apr 27 \'89" "Mar 21 \'85" "Dec 24 \'89" "Jun 08 \'82" "Feb 04 \'88"\n "May 23 \'79" "Dec 17 \'83" "Jan 28 \'85" "Sep 24 \'88" "Sep 25 \'84"\n "Jan 10 \'90" "Nov 02 \'90" "Feb 04 \'92" "Jan 01 \'85" "Aug 03 \'83"\n "Dec 21 \'93" "Apr 09 \'92" "Mar 18 \'77" "May 09 \'91" "Oct 01 \'90"\n "May 02 \'79" "Feb 19 \'86" "Apr 27 \'87" "Feb 27 \'91" "Oct 17 \'90"\n "Mar 31 \'84" "Dec 18 \'78" "Oct 26 \'92" "Mar 23 \'87" "Jan 13 \'91"\n "Apr 14 \'85" "Sep 30 \'82" "Apr 25 \'87" "Nov 18 \'87" "Feb 27 \'85"\n "Jun 14 \'87" "Jan 27 \'83" "Jan 30 \'90" "Nov 06 \'78" "Feb 21 \'89"\n "Dec 29 \'88" "Feb 18 \'86" "Dec 14 \'89" "Aug 06 \'86" "Feb 23 \'90"\n "Dec 23 \'83" "May 02 \'92" "Sep 07 \'78" "Jul 08 \'94" "Jun 14 \'90"\n "Mar 26 \'93" "Jul 20 \'93" "Mar 28 \'89" "Dec 07 \'92" "Jan 25 \'91"\n "Mar 02 \'92" "Jul 15 \'85" "Jan 06 \'82" "Jul 10 \'85" "Aug 07 \'87"\n "Nov 02 \'76" "Dec 02 \'86" "Sep 13 \'90" "Feb 19 \'91" "Jul 06 \'91"\n "Oct 09 \'83" "Nov 01 \'89" "Feb 24 \'93" "Nov 30 \'94" "Jul 20 \'78"\n "Aug 21 \'91" "May 09 \'91" "May 20 \'95" "Sep 13 \'88" "Mar 07 \'90"\n "Jun 24 \'90" "Jun 09 \'88" "Sep 14 \'86" "Jul 27 \'86" "Feb 22 \'91"\n "Jul 27 \'91" "Jan 09 \'86" "Nov 13 \'90" "Oct 10 \'76" "May 09 \'90"\n "Dec 20 \'86" "Dec 08 \'89" "Apr 03 \'87" "Oct 27 \'95" "Mar 28 \'95"\n "Apr 29 \'86" "Jan 16 \'91" "Aug 26 \'95" "Jul 25 \'94" "Oct 06 \'90"\n "Sep 06 \'91" "Apr 07 \'79" "Jun 22 \'83" "May 24 \'91" "May 01 \'84"\n "Jan 02 \'83" "May 15 \'90" "Apr 21 \'86" "Jul 06 \'82" "Feb 07 \'96"\n "May 24 \'90" "Jul 17 \'91" "Apr 13 \'76" "May 08 \'89" "Nov 05 \'88"\n "Jan 30 \'91" "Aug 31 \'81" "Jan 03 \'91" "Apr 25 \'86" "Apr 03 \'82"\n "Oct 06 \'89" "Nov 05 \'84" "Aug 29 \'81" "Mar 02 \'84" "Jul 17 \'85"\n "Feb 24 \'91" "Jun 16 \'92" "Dec 31 \'91" "Oct 11 \'88" "Jan 21 \'89"\n "Dec 02 \'91" "Mar 20 \'92" "May 15 \'87" "Jun 04 \'88" "Sep 07 \'85"\n "Mar 17 \'79" "Apr 20 \'92" "Jun 03 \'92" "Aug 08 \'91" "Jul 22 \'96"\n "May 09 \'80" "Mar 20 \'84" "Jun 05 \'80" "Jun 01 \'86" "May 16 \'84"\n "Jul 26 \'88" "Aug 10 \'91" "Oct 31 \'87" "Feb 09 \'91" "Nov 06 \'87"\n "Aug 13 \'94" "Dec 05 \'91" "Aug 08 \'87" "Dec 23 \'79" "Jan 28 \'85"\n "Sep 29 \'86" "May 20 \'90" "Jan 03 \'88" "Nov 20 \'92" "Feb 17 \'88"\n "Feb 14 \'82" "Feb 29 \'80" "Aug 10 \'89" "Feb 12 \'94" "Apr 22 \'88"\n "Jan 17 \'92" "May 06 \'92" "Aug 12 \'85" "Jul 04 \'90" "Nov 13 \'84"\n "Apr 04 \'93" "Aug 13 \'93"  ...

# %%
df['birthyear'] = df['DOB'].astype(str).str.split("'").str.get(1).astype(int)

# %%
df
# Out:
#         #         DOB     Birth City  S/P Ctry  Nat  HT   Wt  S   Draft  \
# 0     8.0  Feb 25 '87       Muskegon   MI  USA   US  74  218  L  2005.0
# 1    41.0  Jul 16 '87          Edina   MN  USA   US  75  202  L     NaN
# 2    25.0  Jun 18 '90     St. John's   NL  CAN   CA  74  206  L  2008.0
# 3    27.0  Apr 26 '77          Seria  NaN  BRN  NaN  72  200  R  1996.0
# 4    32.0  Jan 03 '91      Kleinburg   ON  CAN   CA  70  187  L     NaN
# 5    42.0  Jun 03 '90         Ottawa   ON  CAN   CA  70  190  R     NaN
# 6     6.0  Aug 21 '80       Kingston   ON  CAN   CA  77  223  L  1998.0
# 7     NaN  Jan 31 '90        Chicago   IL  USA   US  73  210  L     NaN
# 8    39.0  Oct 18 '91    Kansas City   MO  USA   US  76  201  R  2010.0
# 9    27.0  Sep 24 '88        Burnaby   BC  CAN   CA  74  217  L  2007.0
# 10   53.0  May 07 '94     Burlington   ON  CAN   CA  75  212  R  2012.0
# 11   18.0  Feb 05 '89       Munkedal  NaN  SWE   SE  74  211  L  2007.0
# 12   15.0  May 17 '91      Pickering   ON  CAN   CA  73  207  L  2011.0
# 13   58.0  Mar 21 '93         Zurich  NaN  CHE   CH  69  183  L  2013.0
# 14   15.0  Jun 27 '85     Woodbridge   ON  CAN   CA  73  212  L     NaN
# 15   42.0  May 24 '88      Yaroslavl  NaN  RUS   RU  76  198  L  2006.0
# 16   36.0  Aug 12 '88        Milford   CT  USA   US  68  172  R     NaN
# 17   33.0  May 31 '93           Pori  NaN  FIN   FI  75  192  R  2011.0
# 18   38.0  Apr 08 '93     Skellefteå  NaN  SWE   SE  69  172  R  2014.0
# 19   37.0  Apr 01 '91       Winnipeg   MB  CAN   CA  75  215  L  2009.0
# 20   13.0  Jun 05 '89      Riverside   CT  USA   US  68  174  R  2008.0
# 21   22.0  Jun 11 '89        Rouleau   SK  CAN   CA  78  222  L  2007.0
# 22   42.0  May 01 '84    Minneapolis   MN  USA   US  75  221  R  2003.0
# 23   11.0  Mar 17 '89       Vasteras  NaN  SWE   SE  72  198  L  2007.0
# 24   19.0  Nov 23 '87          Gävle  NaN  SWE   SE  73  208  L  2006.0
# 25   47.0  Oct 05 '92           Bern  NaN  CHE   CH  71  190  L  2011.0
# 26   37.0  Oct 27 '91      ANCHORAGE   AK  USA   US  75  195  R     NaN
# 27   12.0  Oct 02 '89    Bowmanville   ON  CAN   CA  73  194  L  2008.0
# 28    2.0  Nov 26 '82       Baudette   MN  USA   US  71  204  L  2002.0
# 29    8.0  Mar 23 '90       Montreal   QC  CAN   CA  73  199  L  2008.0
# ..    ...         ...            ...  ...  ...  ...  ..  ... ..     ...
# 852  26.0  Aug 31 '86       Plymouth   MN  USA   US  77  225  R  2004.0
# 853  25.0  Mar 17 '88        Brandon   MB  CAN   CA  72  201  R  2006.0
# 854  33.0  Feb 06 '88        Reading   MA  USA   US  66  170  L     NaN
# 855   6.0  Mar 20 '83      Kitchener   ON  CAN   CA  72  200  R  2002.0
# 856  46.0  Sep 12 '90        Burnaby   BC  CAN   CA  77  206  L  2008.0
# 857  14.0  Oct 04 '81        Cobourg   ON  CAN   CA  73  189  R  2000.0
# 858  33.0  Oct 20 '89      Greenwich   CT  USA   US  73  216  L  2008.0
# 859  28.0  Mar 16 '91         Barrie   ON  CAN   CA  74  199  L  2009.0
# 860  44.0  Feb 03 '87        Windsor   ON  CAN   CA  73  210  L     NaN
# 861  43.0  Apr 24 '92       Oakville   ON  CAN   CA  71  183  L  2011.0
# 862  43.0  Mar 29 '94        Toronto   ON  CAN   CA  76  210  R  2012.0
# 863  57.0  Apr 12 '88       Evanston   IL  USA   US  72  200  R  2008.0
# 864  26.0  Mar 06 '85        Toronto   ON  CAN   CA  74  207  L  2004.0
# 865  20.0  Feb 21 '84         Canton   MI  USA   US  71  203  R  2002.0
# 866  53.0  Apr 14 '90        Holland   MI  USA   US  74  200  R  2008.0
# 867  45.0  Sep 15 '89     Dusseldorf  NaN  DEU  NaN  75  215  L     NaN
# 868  56.0  Jun 11 '92       Humboldt   SK  CAN   CA  76  210  L  2012.0
# 869  26.0  Mar 12 '93        Burnaby   BC  CAN   CA  74  210  L  2011.0
# 870  39.0  Oct 04 '94    Nizhnekamsk  NaN  RUS   RU  77  232  L  2013.0
# 871  10.0  Oct 06 '93    Nizhnekamsk  NaN  RUS   RU  71  197  L  2012.0
# 872  93.0  Sep 09 '86         Boston   MA  USA   US  73  190  L  2005.0
# 873  51.0  Apr 16 '95         Moscow  NaN  RUS   RU  77  220  L  2013.0
# 874  19.0  May 13 '85       Winnipeg   MB  CAN   CA  75  205  R  2004.0
# 875  40.0  Oct 09 '80       Njurunda  NaN  SWE   SE  72  195  L  1999.0
# 876  93.0  Apr 18 '93      Stockholm  NaN  SWE   SE  74  211  R  2011.0
# 877  28.0  Feb 03 '77           Most  NaN  CZE   CZ  71  190  R  2001.0
# 878  16.0  Sep 01 '87        Toronto   ON  CAN   CA  72  185  L     NaN
# 879   8.0  Jun 16 '78     Elektrenai  NaN  LTU   LT  77  225  L  1996.0
# 880  36.0  Sep 01 '87           Oslo  NaN  NOR   NO  67  179  L     NaN
# 881  16.0  Jan 16 '92  Newport Beach   CA  USA   US  71  188  L  2010.0
#
#        ...     dFenwickImpact  dFenwick60 Days  Ginj  \
# 0      ...              -9.36       -0.60  186  11.0
# 1      ...              10.41       22.57   29   NaN
# 2      ...               0.95        3.33    5   NaN
# 3      ...             -19.42       -2.36  186   5.0
# 4      ...               0.41        2.26    2   NaN
# 5      ...             -20.56      -12.23   54   NaN
# 6      ...               6.21        4.94  186  20.0
# 7      ...               2.45        3.25    8   NaN
# 8      ...               3.85       21.90    2   NaN
# 9      ...             -17.26       -0.77  186   NaN
# 10     ...              -3.28       -2.36   11   NaN
# 11     ...             -45.28       -4.40  186   1.0
# 12     ...             -37.39      -14.32  186   NaN
# 13     ...             -10.55       -6.93   35   NaN
# 14     ...              -4.45      -11.43    8   NaN
# 15     ...              63.66        6.07  186  30.0
# 16     ...              23.20        9.94  186   NaN
# 17     ...              -1.27       -5.21    1   NaN
# 18     ...              -2.54       -2.48   12   NaN
# 19     ...              -1.24       -1.70   48   NaN
# 20     ...             -16.26       -0.97  186   4.0
# 21     ...             -16.16       -2.31  160   NaN
# 22     ...               0.67        0.04  186   1.0
# 23     ...              52.88        4.40  186  30.0
# 24     ...              35.33        1.67  186   NaN
# 25     ...              -2.09       -7.16   60   1.0
# 26     ...               9.56       10.93   18   NaN
# 27     ...             -87.98       -5.23  186  12.0
# 28     ...             -20.28       -7.84  186  64.0
# 29     ...             -19.31       -1.42  186   NaN
# ..     ...                ...         ...  ...   ...
# 852    ...              42.46        2.36  186   2.0
# 853    ...              24.68        4.08  166  39.0
# 854    ...              -8.44      -18.07   11   NaN
# 855    ...            -139.37       -5.40  186   NaN
# 856    ...             100.40        7.37  186   8.0
# 857    ...              11.96        0.65  186   1.0
# 858    ...               9.07        0.53  186   5.0
# 859    ...               1.82        6.93    5   NaN
# 860    ...               1.95        4.76  186  78.0
# 861    ...              -1.62      -28.10   46  18.0
# 862    ...              30.22        2.49  178   9.0
# 863    ...             -94.60       -5.77  186   7.0
# 864    ...              85.03       12.63  186   2.0
# 865    ...              22.66        9.55  186   8.0
# 866    ...               2.47        0.66   62   NaN
# 867    ...               0.62        1.47   26   3.0
# 868    ...              -3.07      -14.64    3   NaN
# 869    ...               2.99       10.24   22   NaN
# 870    ...              -1.06       -6.35    2   NaN
# 871    ...             -88.83       -5.06  186   1.0
# 872    ...             -32.70       -2.86  186   NaN
# 873    ...              26.28        1.72  186   NaN
# 874    ...              14.40        0.82  186   8.0
# 875    ...             -50.04       -2.70  186   4.0
# 876    ...             -42.91       -2.56  186   NaN
# 877    ...               3.98        3.35  186   NaN
# 878    ...              -1.26       -3.66    4   NaN
# 879    ...             -11.44       -0.73  186   8.0
# 880    ...              15.78        0.87  186   4.0
# 881    ...              23.26        2.15  186  31.0
#
#                                         Injury Cap Cost   CHIP Bonuses  \
# 0                               Hand, Shoulder    1.800  0.088   0.000
# 1                                          NaN    0.106  0.000   0.000
# 2                                          NaN    0.017  0.000   0.000
# 3                                  Undisclosed    0.700  0.043   0.000
# 4                                          NaN    0.006  0.000   0.000
# 5                                          NaN    0.167  0.000   0.000
# 6                              Lower body, Flu    3.022  0.854   0.000
# 7                                          NaN    0.076  0.000   0.850
# 8                                          NaN    0.010  0.000   0.110
# 9                                          NaN    2.800  0.000   0.000
# 10                                         NaN    0.053  0.000   0.282
# 11                                     Illness    0.733  0.009   0.000
# 12                                         NaN    0.550  0.000   0.000
# 13                                         NaN    0.141  0.000   0.125
# 14                                         NaN    0.028  0.000   0.000
# 15                             Arm, Concussion    3.283  0.921   0.000
# 16                                         NaN    0.601  0.000   0.000
# 17                                         NaN    0.007  0.000   0.700
# 18                                         NaN    0.042  0.000   0.035
# 19                                         NaN    0.219  0.000   0.000
# 20                          Facial, Upper body    1.150  0.014   0.000
# 21                                         NaN    0.688  0.000   0.000
# 22                                  Concussion    4.500  0.055   0.000
# 23                          Abdominal, Illness    1.500  0.530   0.000
# 24                                         NaN    6.700  0.000   0.000
# 25                                     Illness    0.460  0.017   1.062
# 26                                         NaN    0.131  0.000   0.025
# 27   Hand, Lower body, Undisclosed, Upper body    3.300  0.322   0.000
# 28                         Concussion, Illness    1.500  1.024   0.000
# 29                                         NaN    0.874  0.000   0.000
# ..                                         ...      ...    ...     ...
# 852                                 Lower body    5.600  0.137   0.000
# 853                                   Pectoral    0.513  0.273   0.000
# 854                                        NaN    0.034  0.000   0.000
# 855                                        NaN    5.250  0.000   0.000
# 856                                Undisclosed    2.000  0.122   0.000
# 857                                        Eye    3.650  0.045   0.000
# 858                     Lower body, Upper body    2.000  0.049   0.000
# 859                                        NaN    0.019  0.000   0.000
# 860                      Shoulder, Undisclosed    2.250  2.058   0.000
# 861                                        Leg    0.153  0.203   0.282
# 862                      Head, Leg, Lower body    1.238  0.032   0.400
# 863                                       Hand    2.475  0.211   0.000
# 864                                       Head    1.139  0.032   0.000
# 865                   Foot, Finger, Lower body    5.500  0.402   0.000
# 866                                        NaN    0.292  0.000   0.247
# 867                                        Leg    0.129  0.034   0.058
# 868                                        NaN    0.012  0.000   0.025
# 869                                        NaN    0.109  0.000   0.000
# 870                                        NaN    0.010  0.000   0.133
# 871                                      Groin    3.775  0.046   2.850
# 872                                        NaN    4.658  0.000   0.000
# 873                                        NaN    1.744  0.000   0.850
# 874                                 Lower body    5.750  0.561   0.000
# 875                                       Head    6.083  0.297   0.000
# 876                                        NaN    1.744  0.000   0.850
# 877                                        NaN    3.779  0.000   2.000
# 878                                        NaN    0.013  0.000   0.000
# 879                                        Leg    3.100  0.302   0.000
# 880             Lower body, Shoulder, Soreness    3.500  0.043   0.000
# 881                        Collarbone, Illness    0.900  0.296   0.000
#
#            GVS birthyear
# 0     5.340426        87
# 1    -0.443079        87
# 2    -0.104713        90
# 3     0.980851        77
# 4     0.299817        91
# 5    -0.515580        90
# 6    -5.159574        80
# 7    -0.411370        90
# 8    -0.208694        91
# 9     2.412766        88
# 10   -0.543560        94
# 11   -0.689362        89
# 12    1.000000        91
# 13   -0.279799        93
# 14   -0.009243        85
# 15   -2.814894        88
# 16    5.491489        88
# 17   -0.008602        93
# 18   -0.213864        93
# 19   -0.763967        91
# 20    5.623404        89
# 21   -0.957195        89
# 22    4.295745        84
# 23    4.678723        89
# 24    2.314894        87
# 25    0.298765        92
# 26    0.334523        91
# 27    2.548936        89
# 28   -2.821277        82
# 29   -0.589362        90
# ..         ...       ...
# 852   3.855319        86
# 853   3.052894        88
# 854  -0.103134        88
# 855   4.900000        83
# 856  -2.085106        90
# 857   1.104255        81
# 858   6.914894        89
# 859  -0.408968        91
# 860  -4.217021        87
# 861  -0.036124        92
# 862  -0.514162        94
# 863   3.104255        88
# 864   9.546809        85
# 865  -6.331915        84
# 866  -0.831206        90
# 867  -0.110890        89
# 868  -0.206658        92
# 869  -0.093503        93
# 870  -0.208694        94
# 871  -6.261702        93
# 872  -0.540426        86
# 873  -2.140426        95
# 874 -10.463830        85
# 875  -1.672340        80
# 876   6.159574        93
# 877  -1.970213        77
# 878  -0.202494        87
# 879  -7.525532        78
# 880   3.423404        87
# 881   6.255319        92
#
# [882 rows x 121 columns]

# %% [markdown]
# # Young Players (24 years old or younger) for the United States:

# %%
young_usa_players = df[(df['Ctry'] == 'USA') & (df['birthyear'] >= 94 )]
young_usa_players[["First Name", "Last Name"]]
# Out:
#     First Name   Last Name
# 158     Andrew        Copp
# 268       Alex  Galchenyuk
# 340       Ryan     Hartman
# 396       Seth       Jones
# 506     Stefan     Matteau
# 682      Kerby      Rychel
# 687     Henrik  Samuelsson
# 815      Jacob      Trouba

# %% [markdown]
# # Young Players (24 years old or younger) for Canada:

# %%
young_can_players = df[(df['Ctry'] == 'CAN') & (df['birthyear'] >= 94 )]
young_can_players[["First Name", "Last Name"]]
# Out:
#     First Name  Last Name
# 10        Josh   Anderson
# 45         Sam    Bennett
# 199   Jonathan     Drouin
# 202    Anthony    Duclair
# 203       Matt      Dumba
# 214      Aaron     Ekblad
# 369         Bo     Horvat
# 427     Slater   Koekkoek
# 441      Brett      Kulak
# 455      Scott   Laughton
# 457     Curtis      Lazar
# 487     Nathan  MacKinnon
# 538       Sean    Monahan
# 575    Darnell      Nurse
# 578       Liam    O'Brien
# 626      Emile    Poirier
# 633    Derrick    Pouliot
# 656    Griffin   Reinhart
# 658        Sam   Reinhart
# 665     Morgan     Rielly
# 719      Damon   Severson
# 805      Chris    Tierney
# 862        Tom     Wilson

# %% [markdown]
# # Old Players (36 years old or older) for the United States:

# %%
old_usa_players = df[(df['Ctry'] == 'USA') & (df['birthyear'] <= 80 )]

# %%
old_usa_players[["First Name", "Last Name"]]
# Out:
#        First Name Last Name
# 148          Erik      Cole
# 170          Matt    Cullen
# 284         Brian    Gionta
# 297         Scott     Gomez
# 461         David   Legwand
# 464        Jordan   Leopold
# 470  John-Michael     Liles
# 492          Ryan    Malone
# 588        Brooks     Orpik
# 707           Rob   Scuderi

# %% [markdown]
# # Old Players (36 years old or younger) for Canada:

# %%
old_can_players = df[(df['Ctry'] == 'CAN') & (df['birthyear'] <= 80 )]

# %%
old_can_players[["First Name", "Last Name"]]
# Out:
#     First Name   Last Name
# 6        Bryan       Allen
# 36    Francois  Beauchemin
# 74        Eric     Boulton
# 86         Dan       Boyle
# 91        Eric      Brewer
# 92      Daniel      Briere
# 115      Brian    Campbell
# 130      Jason     Chimera
# 136     Daniel      Cleary
# 157       Matt       Cooke
# 193      Shane        Doan
# 206     Pascal      Dupuis
# 240     Andrew     Ference
# 245     Vernon     Fiddler
# 247       Mike      Fisher
# 266      Simon       Gagne
# 334      Scott      Hannan
# 367      Shawn     Horcoff
# 376     Jarome      Iginla
# 412      Chris       Kelly
# 444      Chris      Kunitz
# 458    Vincent  Lecavalier
# 489      Manny    Malhotra
# 500    Patrick     Marleau
# 536     Willie    Mitchell
# 539    Dominic       Moore
# 543    Brenden      Morrow
# 560      Chris        Neil
# 619      Chris    Phillips
# 660       Mike     Ribeiro
# 661       Brad    Richards
# 671   Stephane     Robidas
# 683    Michael       Ryder
# 686      Bryce    Salvador
# 753     Martin   St. Louis
# 779       Brad      Stuart
# 792       Alex     Tanguay
# 803        Joe    Thornton
# 804      Shawn    Thornton
# 843       Joel        Ward
# 845       Mike      Weaver

# %% [markdown]
# # Let's examine the correlation between height and weight

# %%
df['HT'].describe()
# Out:
# count    882.000000
# mean      73.091837
# std        2.111952
# min       65.000000
# 25%       72.000000
# 50%       73.000000
# 75%       74.000000
# max       81.000000
# Name: HT, dtype: float64

# %%
df['Wt'].describe()
# Out:
# count    882.000000
# mean     201.626984
# std       14.831795
# min      150.000000
# 25%      190.000000
# 50%      201.000000
# 75%      211.000000
# max      260.000000
# Name: Wt, dtype: float64

# %% [markdown]
# # And a visual of the correlation...nice:

# %%
plt.style.use('ggplot')

# %%
df.plot(kind='scatter', x='Wt', y='HT')

# %% [markdown]
# # Let's examine how many lefty's versus righty's (in shooting) each country has:

# %%
df['S'].value_counts()
# Out:
# L    554
# R    328
# Name: S, dtype: int64

# %%
df.groupby(['Ctry', 'S']).agg(['count'])
# Out:
#            #   DOB Birth City   S/P   Nat    HT    Wt Draft Round Overall  \
#        count count      count count count count count count count   count
# Ctry S
# AUT  L     4     4          4     0     1     4     4     3     3       3
#      R     1     1          1     0     0     1     1     1     1       1
# BLR  R     1     1          1     0     1     1     1     0     0       0
# BRA  L     1     1          1     0     1     1     1     1     1       1
# BRN  R     1     1          1     0     0     1     1     1     1       1
# CAN  L   280   282        282   282   281   282   282   232   232     232
#      R   169   171        171   171   171   171   171   150   150     150
# CHE  L     7     7          7     0     7     7     7     7     7       7
#      R     3     3          3     0     3     3     3     1     1       1
# CZE  L    22    22         22     0    22    22    22    21    21      21
#      R    11    11         11     0    11    11    11     9     9       9
# DEU  L     8     8          8     0     7     8     8     7     7       7
#      R     1     1          1     0     1     1     1     1     1       1
# DNK  L     6     6          6     0     6     6     6     6     6       6
#      R     1     1          1     0     1     1     1     1     1       1
# EST  L     1     1          1     0     1     1     1     1     1       1
# FIN  L    20    20         20     0    20    20    20    20    20      20
#      R     5     5          5     0     5     5     5     5     5       5
# FRA  L     3     3          3     0     3     3     3     1     1       1
# HRV  R     1     1          1     0     0     1     1     0     0       0
# ITA  L     1     1          1     0     0     1     1     1     1       1
# LTU  L     1     1          1     0     1     1     1     1     1       1
# LVA  L     2     2          2     0     2     2     2     1     1       1
# NOR  L     1     1          1     0     1     1     1     0     0       0
# RUS  L    24    24         24     0    24    24    24    23    23      23
#      R     5     5          5     0     5     5     5     5     5       5
# SVK  L    11    11         11     0    11    11    11    11    11      11
# SVN  L     1     1          1     0     1     1     1     1     1       1
# SWE  L    44    45         45     0    45    45    45    44    44      44
#      R    19    19         19     0    19    19    19    17    17      17
# USA  L   110   114        114   114   114   114   114    93    93      93
#      R   107   108        108   108   108   108   108    85    85      85
#
#           ...    dFenwickImpact dFenwick60  Days  Ginj Injury Cap Cost  CHIP  \
#           ...             count      count count count  count    count count
# Ctry S    ...
# AUT  L    ...                 4          4     4     3      3        4     4
#      R    ...                 1          1     1     1      1        1     1
# BLR  R    ...                 1          1     1     0      0        1     1
# BRA  L    ...                 1          1     1     1      1        1     1
# BRN  R    ...                 1          1     1     1      1        1     1
# CAN  L    ...               282        282   282   156    156      282   282
#      R    ...               171        171   171    96     96      171   171
# CHE  L    ...                 7          7     7     5      5        7     7
#      R    ...                 3          3     3     2      2        3     3
# CZE  L    ...                22         22    22    14     14       22    22
#      R    ...                11         11    11     8      8       11    11
# DEU  L    ...                 8          8     8     5      5        8     8
#      R    ...                 1          1     1     1      1        1     1
# DNK  L    ...                 6          6     6     3      3        6     6
#      R    ...                 1          1     1     1      1        1     1
# EST  L    ...                 1          1     1     1      1        1     1
# FIN  L    ...                20         20    20    14     14       20    20
#      R    ...                 5          5     5     3      3        5     5
# FRA  L    ...                 3          3     3     0      0        3     3
# HRV  R    ...                 1          1     1     1      1        1     1
# ITA  L    ...                 1          1     1     1      1        1     1
# LTU  L    ...                 1          1     1     1      1        1     1
# LVA  L    ...                 2          2     2     1      1        2     2
# NOR  L    ...                 1          1     1     1      1        1     1
# RUS  L    ...                24         24    24    13     13       24    24
#      R    ...                 5          5     5     2      2        5     5
# SVK  L    ...                11         11    11     8      8       11    11
# SVN  L    ...                 1          1     1     1      1        1     1
# SWE  L    ...                45         45    45    27     27       45    45
#      R    ...                19         19    19     6      6       19    19
# USA  L    ...               114        114   114    54     54      114   114
#      R    ...               108        108   108    52     52      108   108
#
#        Bonuses   GVS birthyear
#          count count     count
# Ctry S
# AUT  L       4     4         4
#      R       1     1         1
# BLR  R       1     1         1
# BRA  L       1     1         1
# BRN  R       1     1         1
# CAN  L     282   282       282
#      R     171   171       171
# CHE  L       7     7         7
#      R       3     3         3
# CZE  L      22    22        22
#      R      11    11        11
# DEU  L       8     8         8
#      R       1     1         1
# DNK  L       6     6         6
#      R       1     1         1
# EST  L       1     1         1
# FIN  L      20    20        20
#      R       5     5         5
# FRA  L       3     3         3
# HRV  R       1     1         1
# ITA  L       1     1         1
# LTU  L       1     1         1
# LVA  L       2     2         2
# NOR  L       1     1         1
# RUS  L      24    24        24
#      R       5     5         5
# SVK  L      11    11        11
# SVN  L       1     1         1
# SWE  L      45    45        45
#      R      19    19        19
# USA  L     114   114       114
#      R     108   108       108
#
# [32 rows x 119 columns]

# %% [markdown]
# # Interesting...Canada has significantly more left-handed shooters (280) than right-handed shooters. Meanwhile, the USA is  pretty even with 110 lefty's and 107 righty's.

# %%
usa_left_shot = df[(df['Ctry'] == 'USA') & (df['S'] == 'L')]

# %%
usa_left_shot[["First Name", "Last Name"]]
# Out:
#     First Name     Last Name
# 0       Justin    Abdelkader
# 1         Will         Acton
# 7        Conor         Allen
# 28       Keith       Ballard
# 32        Matt    Bartkowski
# 56     Anthony       Bitetto
# 67     Brandon        Bollig
# 68        Nick        Bonino
# 69       David         Booth
# 73        Reid       Boucher
# 79        Ryan       Bourque
# 81     Drayson        Bowman
# 85       Brian         Boyle
# 90          TJ       Brennan
# 108      Chris        Butler
# 118       Paul         Carey
# 119    Matthew         Carle
# 124       Ryan        Carter
# 148       Erik          Cole
# 149        Ian          Cole
# 155      Chris        Conner
# 158     Andrew          Copp
# 163       Sean     Couturier
# 170       Matt        Cullen
# 173      Jerry       D'Amigo
# 184      Danny      DeKeyser
# 194       Matt       Donovan
# 200    Brandon      Dubinsky
# 205      Brian      Dumoulin
# 230        Tim        Erixon
# ..         ...           ...
# 588     Brooks         Orpik
# 595        Max    Pacioretty
# 606       Zach        Parise
# 623        Joe       Piskula
# 634      Shane        Prince
# 682      Kerby        Rychel
# 684    Brandon          Saad
# 694        Tim      Schaller
# 698    Cameron     Schilling
# 700       Nate       Schmidt
# 707        Rob       Scuderi
# 716        Tim       Sestito
# 717        Tom       Sestito
# 737        Jim        Slater
# 773      Brian        Strait
# 780       Mark        Stuart
# 782      Chris       Summers
# 784       Ryan         Suter
# 791       Eric      Tangradi
# 801       Nate      Thompson
# 807     Jarred       Tinordi
# 820       R.J.      Umberger
# 823      James  van Riemsdyk
# 825      Chris    VandeVelde
# 844      David     Warsofsky
# 846       Mike         Weber
# 854        Joe       Whitney
# 858      Colin        Wilson
# 872      Keith        Yandle
# 881      Jason        Zucker
#
# [114 rows x 2 columns]

# %%
can_left_shot = df[(df['Ctry'] == 'CAN') & (df['S'] == 'L')]

# %%
can_left_shot[["First Name", "Last Name"]]
# Out:
#        First Name      Last Name
# 2            Luke           Adam
# 4          Andrew       Agozzino
# 6           Bryan          Allen
# 9            Karl         Alzner
# 12           Andy       Andreoff
# 14           Mike      Angelidis
# 19         Carter         Ashton
# 21          Keith          Aulie
# 27           Josh         Bailey
# 29           Mark       Barberio
# 33         Victor        Bartley
# 36       Francois     Beauchemin
# 37         Nathan       Beaulieu
# 39           Matt       Beleskey
# 42          Jamie           Benn
# 43         Jordie           Benn
# 45            Sam        Bennett
# 46          Andre         Benoit
# 52          Bryan        Bickell
# 64      Alexandre         Bolduc
# 70        Patrick      Bordeleau
# 71           Mark     Borowiecki
# 74           Eric        Boulton
# 75          Lance          Bouma
# 76        Michael      Bournival
# 77        Gabriel        Bourque
# 78           Rene        Bourque
# 80            Jay    Bouwmeester
# 83           Zach        Boychuk
# 88         Derick       Brassard
# ..            ...            ...
# 763     Alexander          Steen
# 768          Karl       Stollery
# 771       Clayton         Stoner
# 776           Ben         Street
# 779          Brad         Stuart
# 786         Brett         Sutter
# 789           Max         Talbot
# 792          Alex        Tanguay
# 796          John        Tavares
# 799         Chris          Terry
# 803           Joe       Thornton
# 805         Chris        Tierney
# 809      Jonathan          Toews
# 817          Dana         Tyrell
# 821       Scottie        Upshall
# 822         David  Van Der Gulik
# 827        Philip         Varone
# 829      Stephane       Veilleux
# 830       Antoine       Vermette
# 836  Marc-Edouard         Vlasic
# 838         Aaron       Volpatti
# 850       Stephen          Weiss
# 856       Patrick      Wiercioch
# 859       Garrett         Wilson
# 860          Ryan         Wilson
# 861         Scott         Wilson
# 864        Daniel         Winnik
# 868       Brendan          Woods
# 869         Tyler    Wotherspoon
# 878         Harry    Zolnierczyk
#
# [282 rows x 2 columns]

# %%
usa_right_shot = df[(df['Ctry'] == 'USA') & (df['S'] == 'R')]

# %%
usa_right_shot[["First Name", "Last Name"]]
# Out:
#     First Name     Last Name
# 8         Mark           Alt
# 16        Mark     Arcobello
# 20         Cam      Atkinson
# 22       David        Backes
# 26       Casey        Bailey
# 44        Beau       Bennett
# 51         Stu        Bickel
# 57        Nick      Bjugstad
# 59    Jonathon          Blum
# 63        Zach      Bogosian
# 65       Jared          Boll
# 89      Justin         Braun
# 98       Chris         Brown
# 99      Dustin         Brown
# 100       J.T.         Brown
# 101       Mike         Brown
# 102    Patrick         Brown
# 105       Adam        Burish
# 109     Dustin     Byfuglien
# 111       Ryan      Callahan
# 120       John       Carlson
# 134        Mat         Clark
# 137       Adam    Clendening
# 153       Erik        Condra
# 165    Charlie         Coyle
# 168       B.J.      Crombeen
# 207    Patrick         Dwyer
# 236     Justin         Faulk
# 237       Mark         Fayne
# 242      Brian        Ferlin
# ..         ...           ...
# 653      Dylan         Reese
# 672      Bobby        Robins
# 676       Chad      Ruhwedel
# 679      Bryan          Rust
# 681      Bobby          Ryan
# 687     Henrik    Samuelsson
# 701     Jordan     Schroeder
# 722      Kevin   Shattenkirk
# 727       Drew         Shore
# 728       Nick         Shore
# 734       Mike         Sislo
# 735       Jack        Skille
# 739        Ben         Smith
# 742      Craig         Smith
# 757       Drew      Stafford
# 764        Lee     Stempniak
# 765      Derek        Stepan
# 785    Brandon        Sutter
# 797       Matt      Tennyson
# 812    Vincent      Trocheck
# 813      Corey         Tropp
# 814       Zach       Trotman
# 815      Jacob        Trouba
# 824     Trevor  van Riemsdyk
# 835        Joe        Vitale
# 842      Chris        Wagner
# 852      Blake       Wheeler
# 863      Tommy       Wingels
# 865      James    Wisniewski
# 866       Luke     Witkowski
#
# [108 rows x 2 columns]

# %%
can_right_shot = df[(df['Ctry'] == 'CAN') & (df['S'] == 'R')]

# %%
can_right_shot[["First Name", "Last Name"]]
# Out:
#       First Name  Last Name
# 5          Jason     Akeson
# 10          Josh   Anderson
# 31         Tyson     Barrie
# 34          Kyle       Baun
# 35           Jay     Beagle
# 38        Taylor       Beck
# 41         Brett  Bellemore
# 48       Patrice   Bergeron
# 50         Steve    Bernier
# 53          Alex      Biega
# 54         Danny      Biega
# 55         Kevin     Bieksa
# 58         Jesse    Blacker
# 60          Mike    Blunden
# 61          Troy      Bodie
# 66          Dave    Bolland
# 72        Robert   Bortuzzo
# 82        Johnny    Boychuk
# 84          Brad      Boyes
# 86           Dan      Boyle
# 87         Tyler      Bozak
# 92        Daniel     Briere
# 95          Kyle   Brodziak
# 97          Troy    Brouwer
# 106        Brent      Burns
# 122          Sam    Carrick
# 123         Jeff     Carter
# 125         Cody       Ceci
# 129         Alex   Chiasson
# 135        David   Clarkson
# ..           ...        ...
# 749        Jason     Spezza
# 751        Jared   Spurgeon
# 760       Steven    Stamkos
# 766        Chris    Stewart
# 767       Jarret      Stoll
# 769         Mark      Stone
# 770      Michael      Stone
# 772        Tyson   Strachan
# 778         Ryan     Strome
# 781         P.K.     Subban
# 787        Brody     Sutter
# 788       Jordan     Szwarz
# 790  Christopher      Tanev
# 800    Christian     Thomas
# 802        Chris   Thorburn
# 804        Shawn   Thornton
# 810        Tyler    Toffoli
# 811       Jordin     Tootoo
# 816         Kyle     Turris
# 831         Kris   Versteeg
# 832       Linden        Vey
# 843         Joel       Ward
# 845         Mike     Weaver
# 847         Shea      Weber
# 849         Dale      Weise
# 853         Ryan      White
# 855       Dennis    Wideman
# 857       Justin   Williams
# 862          Tom     Wilson
# 874       Travis      Zajac
#
# [171 rows x 2 columns]

# %% [markdown]
# # Correlation between Country and Draft Year

# %%
plt.style.use('seaborn-deep')
df.head(5).plot(kind='bar', x='Ctry', y='Draft')

# %%
df
# Out:
#         #         DOB     Birth City  S/P Ctry  Nat  HT   Wt  S   Draft  \
# 0     8.0  Feb 25 '87       Muskegon   MI  USA   US  74  218  L  2005.0
# 1    41.0  Jul 16 '87          Edina   MN  USA   US  75  202  L     NaN
# 2    25.0  Jun 18 '90     St. John's   NL  CAN   CA  74  206  L  2008.0
# 3    27.0  Apr 26 '77          Seria  NaN  BRN  NaN  72  200  R  1996.0
# 4    32.0  Jan 03 '91      Kleinburg   ON  CAN   CA  70  187  L     NaN
# 5    42.0  Jun 03 '90         Ottawa   ON  CAN   CA  70  190  R     NaN
# 6     6.0  Aug 21 '80       Kingston   ON  CAN   CA  77  223  L  1998.0
# 7     NaN  Jan 31 '90        Chicago   IL  USA   US  73  210  L     NaN
# 8    39.0  Oct 18 '91    Kansas City   MO  USA   US  76  201  R  2010.0
# 9    27.0  Sep 24 '88        Burnaby   BC  CAN   CA  74  217  L  2007.0
# 10   53.0  May 07 '94     Burlington   ON  CAN   CA  75  212  R  2012.0
# 11   18.0  Feb 05 '89       Munkedal  NaN  SWE   SE  74  211  L  2007.0
# 12   15.0  May 17 '91      Pickering   ON  CAN   CA  73  207  L  2011.0
# 13   58.0  Mar 21 '93         Zurich  NaN  CHE   CH  69  183  L  2013.0
# 14   15.0  Jun 27 '85     Woodbridge   ON  CAN   CA  73  212  L     NaN
# 15   42.0  May 24 '88      Yaroslavl  NaN  RUS   RU  76  198  L  2006.0
# 16   36.0  Aug 12 '88        Milford   CT  USA   US  68  172  R     NaN
# 17   33.0  May 31 '93           Pori  NaN  FIN   FI  75  192  R  2011.0
# 18   38.0  Apr 08 '93     Skellefteå  NaN  SWE   SE  69  172  R  2014.0
# 19   37.0  Apr 01 '91       Winnipeg   MB  CAN   CA  75  215  L  2009.0
# 20   13.0  Jun 05 '89      Riverside   CT  USA   US  68  174  R  2008.0
# 21   22.0  Jun 11 '89        Rouleau   SK  CAN   CA  78  222  L  2007.0
# 22   42.0  May 01 '84    Minneapolis   MN  USA   US  75  221  R  2003.0
# 23   11.0  Mar 17 '89       Vasteras  NaN  SWE   SE  72  198  L  2007.0
# 24   19.0  Nov 23 '87          Gävle  NaN  SWE   SE  73  208  L  2006.0
# 25   47.0  Oct 05 '92           Bern  NaN  CHE   CH  71  190  L  2011.0
# 26   37.0  Oct 27 '91      ANCHORAGE   AK  USA   US  75  195  R     NaN
# 27   12.0  Oct 02 '89    Bowmanville   ON  CAN   CA  73  194  L  2008.0
# 28    2.0  Nov 26 '82       Baudette   MN  USA   US  71  204  L  2002.0
# 29    8.0  Mar 23 '90       Montreal   QC  CAN   CA  73  199  L  2008.0
# ..    ...         ...            ...  ...  ...  ...  ..  ... ..     ...
# 852  26.0  Aug 31 '86       Plymouth   MN  USA   US  77  225  R  2004.0
# 853  25.0  Mar 17 '88        Brandon   MB  CAN   CA  72  201  R  2006.0
# 854  33.0  Feb 06 '88        Reading   MA  USA   US  66  170  L     NaN
# 855   6.0  Mar 20 '83      Kitchener   ON  CAN   CA  72  200  R  2002.0
# 856  46.0  Sep 12 '90        Burnaby   BC  CAN   CA  77  206  L  2008.0
# 857  14.0  Oct 04 '81        Cobourg   ON  CAN   CA  73  189  R  2000.0
# 858  33.0  Oct 20 '89      Greenwich   CT  USA   US  73  216  L  2008.0
# 859  28.0  Mar 16 '91         Barrie   ON  CAN   CA  74  199  L  2009.0
# 860  44.0  Feb 03 '87        Windsor   ON  CAN   CA  73  210  L     NaN
# 861  43.0  Apr 24 '92       Oakville   ON  CAN   CA  71  183  L  2011.0
# 862  43.0  Mar 29 '94        Toronto   ON  CAN   CA  76  210  R  2012.0
# 863  57.0  Apr 12 '88       Evanston   IL  USA   US  72  200  R  2008.0
# 864  26.0  Mar 06 '85        Toronto   ON  CAN   CA  74  207  L  2004.0
# 865  20.0  Feb 21 '84         Canton   MI  USA   US  71  203  R  2002.0
# 866  53.0  Apr 14 '90        Holland   MI  USA   US  74  200  R  2008.0
# 867  45.0  Sep 15 '89     Dusseldorf  NaN  DEU  NaN  75  215  L     NaN
# 868  56.0  Jun 11 '92       Humboldt   SK  CAN   CA  76  210  L  2012.0
# 869  26.0  Mar 12 '93        Burnaby   BC  CAN   CA  74  210  L  2011.0
# 870  39.0  Oct 04 '94    Nizhnekamsk  NaN  RUS   RU  77  232  L  2013.0
# 871  10.0  Oct 06 '93    Nizhnekamsk  NaN  RUS   RU  71  197  L  2012.0
# 872  93.0  Sep 09 '86         Boston   MA  USA   US  73  190  L  2005.0
# 873  51.0  Apr 16 '95         Moscow  NaN  RUS   RU  77  220  L  2013.0
# 874  19.0  May 13 '85       Winnipeg   MB  CAN   CA  75  205  R  2004.0
# 875  40.0  Oct 09 '80       Njurunda  NaN  SWE   SE  72  195  L  1999.0
# 876  93.0  Apr 18 '93      Stockholm  NaN  SWE   SE  74  211  R  2011.0
# 877  28.0  Feb 03 '77           Most  NaN  CZE   CZ  71  190  R  2001.0
# 878  16.0  Sep 01 '87        Toronto   ON  CAN   CA  72  185  L     NaN
# 879   8.0  Jun 16 '78     Elektrenai  NaN  LTU   LT  77  225  L  1996.0
# 880  36.0  Sep 01 '87           Oslo  NaN  NOR   NO  67  179  L     NaN
# 881  16.0  Jan 16 '92  Newport Beach   CA  USA   US  71  188  L  2010.0
#
#         ...      dFenwickImpact  dFenwick60 Days  Ginj  \
# 0       ...               -9.36       -0.60  186  11.0
# 1       ...               10.41       22.57   29   NaN
# 2       ...                0.95        3.33    5   NaN
# 3       ...              -19.42       -2.36  186   5.0
# 4       ...                0.41        2.26    2   NaN
# 5       ...              -20.56      -12.23   54   NaN
# 6       ...                6.21        4.94  186  20.0
# 7       ...                2.45        3.25    8   NaN
# 8       ...                3.85       21.90    2   NaN
# 9       ...              -17.26       -0.77  186   NaN
# 10      ...               -3.28       -2.36   11   NaN
# 11      ...              -45.28       -4.40  186   1.0
# 12      ...              -37.39      -14.32  186   NaN
# 13      ...              -10.55       -6.93   35   NaN
# 14      ...               -4.45      -11.43    8   NaN
# 15      ...               63.66        6.07  186  30.0
# 16      ...               23.20        9.94  186   NaN
# 17      ...               -1.27       -5.21    1   NaN
# 18      ...               -2.54       -2.48   12   NaN
# 19      ...               -1.24       -1.70   48   NaN
# 20      ...              -16.26       -0.97  186   4.0
# 21      ...              -16.16       -2.31  160   NaN
# 22      ...                0.67        0.04  186   1.0
# 23      ...               52.88        4.40  186  30.0
# 24      ...               35.33        1.67  186   NaN
# 25      ...               -2.09       -7.16   60   1.0
# 26      ...                9.56       10.93   18   NaN
# 27      ...              -87.98       -5.23  186  12.0
# 28      ...              -20.28       -7.84  186  64.0
# 29      ...              -19.31       -1.42  186   NaN
# ..      ...                 ...         ...  ...   ...
# 852     ...               42.46        2.36  186   2.0
# 853     ...               24.68        4.08  166  39.0
# 854     ...               -8.44      -18.07   11   NaN
# 855     ...             -139.37       -5.40  186   NaN
# 856     ...              100.40        7.37  186   8.0
# 857     ...               11.96        0.65  186   1.0
# 858     ...                9.07        0.53  186   5.0
# 859     ...                1.82        6.93    5   NaN
# 860     ...                1.95        4.76  186  78.0
# 861     ...               -1.62      -28.10   46  18.0
# 862     ...               30.22        2.49  178   9.0
# 863     ...              -94.60       -5.77  186   7.0
# 864     ...               85.03       12.63  186   2.0
# 865     ...               22.66        9.55  186   8.0
# 866     ...                2.47        0.66   62   NaN
# 867     ...                0.62        1.47   26   3.0
# 868     ...               -3.07      -14.64    3   NaN
# 869     ...                2.99       10.24   22   NaN
# 870     ...               -1.06       -6.35    2   NaN
# 871     ...              -88.83       -5.06  186   1.0
# 872     ...              -32.70       -2.86  186   NaN
# 873     ...               26.28        1.72  186   NaN
# 874     ...               14.40        0.82  186   8.0
# 875     ...              -50.04       -2.70  186   4.0
# 876     ...              -42.91       -2.56  186   NaN
# 877     ...                3.98        3.35  186   NaN
# 878     ...               -1.26       -3.66    4   NaN
# 879     ...              -11.44       -0.73  186   8.0
# 880     ...               15.78        0.87  186   4.0
# 881     ...               23.26        2.15  186  31.0
#
#                                         Injury Cap Cost   CHIP Bonuses  \
# 0                               Hand, Shoulder    1.800  0.088   0.000
# 1                                          NaN    0.106  0.000   0.000
# 2                                          NaN    0.017  0.000   0.000
# 3                                  Undisclosed    0.700  0.043   0.000
# 4                                          NaN    0.006  0.000   0.000
# 5                                          NaN    0.167  0.000   0.000
# 6                              Lower body, Flu    3.022  0.854   0.000
# 7                                          NaN    0.076  0.000   0.850
# 8                                          NaN    0.010  0.000   0.110
# 9                                          NaN    2.800  0.000   0.000
# 10                                         NaN    0.053  0.000   0.282
# 11                                     Illness    0.733  0.009   0.000
# 12                                         NaN    0.550  0.000   0.000
# 13                                         NaN    0.141  0.000   0.125
# 14                                         NaN    0.028  0.000   0.000
# 15                             Arm, Concussion    3.283  0.921   0.000
# 16                                         NaN    0.601  0.000   0.000
# 17                                         NaN    0.007  0.000   0.700
# 18                                         NaN    0.042  0.000   0.035
# 19                                         NaN    0.219  0.000   0.000
# 20                          Facial, Upper body    1.150  0.014   0.000
# 21                                         NaN    0.688  0.000   0.000
# 22                                  Concussion    4.500  0.055   0.000
# 23                          Abdominal, Illness    1.500  0.530   0.000
# 24                                         NaN    6.700  0.000   0.000
# 25                                     Illness    0.460  0.017   1.062
# 26                                         NaN    0.131  0.000   0.025
# 27   Hand, Lower body, Undisclosed, Upper body    3.300  0.322   0.000
# 28                         Concussion, Illness    1.500  1.024   0.000
# 29                                         NaN    0.874  0.000   0.000
# ..                                         ...      ...    ...     ...
# 852                                 Lower body    5.600  0.137   0.000
# 853                                   Pectoral    0.513  0.273   0.000
# 854                                        NaN    0.034  0.000   0.000
# 855                                        NaN    5.250  0.000   0.000
# 856                                Undisclosed    2.000  0.122   0.000
# 857                                        Eye    3.650  0.045   0.000
# 858                     Lower body, Upper body    2.000  0.049   0.000
# 859                                        NaN    0.019  0.000   0.000
# 860                      Shoulder, Undisclosed    2.250  2.058   0.000
# 861                                        Leg    0.153  0.203   0.282
# 862                      Head, Leg, Lower body    1.238  0.032   0.400
# 863                                       Hand    2.475  0.211   0.000
# 864                                       Head    1.139  0.032   0.000
# 865                   Foot, Finger, Lower body    5.500  0.402   0.000
# 866                                        NaN    0.292  0.000   0.247
# 867                                        Leg    0.129  0.034   0.058
# 868                                        NaN    0.012  0.000   0.025
# 869                                        NaN    0.109  0.000   0.000
# 870                                        NaN    0.010  0.000   0.133
# 871                                      Groin    3.775  0.046   2.850
# 872                                        NaN    4.658  0.000   0.000
# 873                                        NaN    1.744  0.000   0.850
# 874                                 Lower body    5.750  0.561   0.000
# 875                                       Head    6.083  0.297   0.000
# 876                                        NaN    1.744  0.000   0.850
# 877                                        NaN    3.779  0.000   2.000
# 878                                        NaN    0.013  0.000   0.000
# 879                                        Leg    3.100  0.302   0.000
# 880             Lower body, Shoulder, Soreness    3.500  0.043   0.000
# 881                        Collarbone, Illness    0.900  0.296   0.000
#
#            GVS   birthyear
# 0     5.340426  Feb 25 '87
# 1    -0.443079  Jul 16 '87
# 2    -0.104713  Jun 18 '90
# 3     0.980851  Apr 26 '77
# 4     0.299817  Jan 03 '91
# 5    -0.515580  Jun 03 '90
# 6    -5.159574  Aug 21 '80
# 7    -0.411370  Jan 31 '90
# 8    -0.208694  Oct 18 '91
# 9     2.412766  Sep 24 '88
# 10   -0.543560  May 07 '94
# 11   -0.689362  Feb 05 '89
# 12    1.000000  May 17 '91
# 13   -0.279799  Mar 21 '93
# 14   -0.009243  Jun 27 '85
# 15   -2.814894  May 24 '88
# 16    5.491489  Aug 12 '88
# 17   -0.008602  May 31 '93
# 18   -0.213864  Apr 08 '93
# 19   -0.763967  Apr 01 '91
# 20    5.623404  Jun 05 '89
# 21   -0.957195  Jun 11 '89
# 22    4.295745  May 01 '84
# 23    4.678723  Mar 17 '89
# 24    2.314894  Nov 23 '87
# 25    0.298765  Oct 05 '92
# 26    0.334523  Oct 27 '91
# 27    2.548936  Oct 02 '89
# 28   -2.821277  Nov 26 '82
# 29   -0.589362  Mar 23 '90
# ..         ...         ...
# 852   3.855319  Aug 31 '86
# 853   3.052894  Mar 17 '88
# 854  -0.103134  Feb 06 '88
# 855   4.900000  Mar 20 '83
# 856  -2.085106  Sep 12 '90
# 857   1.104255  Oct 04 '81
# 858   6.914894  Oct 20 '89
# 859  -0.408968  Mar 16 '91
# 860  -4.217021  Feb 03 '87
# 861  -0.036124  Apr 24 '92
# 862  -0.514162  Mar 29 '94
# 863   3.104255  Apr 12 '88
# 864   9.546809  Mar 06 '85
# 865  -6.331915  Feb 21 '84
# 866  -0.831206  Apr 14 '90
# 867  -0.110890  Sep 15 '89
# 868  -0.206658  Jun 11 '92
# 869  -0.093503  Mar 12 '93
# 870  -0.208694  Oct 04 '94
# 871  -6.261702  Oct 06 '93
# 872  -0.540426  Sep 09 '86
# 873  -2.140426  Apr 16 '95
# 874 -10.463830  May 13 '85
# 875  -1.672340  Oct 09 '80
# 876   6.159574  Apr 18 '93
# 877  -1.970213  Feb 03 '77
# 878  -0.202494  Sep 01 '87
# 879  -7.525532  Jun 16 '78
# 880   3.423404  Sep 01 '87
# 881   6.255319  Jan 16 '92
#
# [882 rows x 121 columns]
